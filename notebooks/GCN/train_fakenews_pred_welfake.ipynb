# %% [markdown]
# # GCN Pipeline — Train on FakeNews → Predict on WelFake
#
# **Pipeline đầy đủ trong một notebook:**
#
# ```
# true.csv + fake.csv          WELFake_Dataset.csv
#        │                            │
#        ▼                            │
#  [1] Load & Preprocess              │
#        │                            │
#        ▼                            │
#  [2] TF-IDF + KNN Graph             │
#        │                            │
#        ▼                            │
#  [3] Train GCN Model                │
#        │                            │
#        ▼                            │
#  [4] Evaluate on FakeNews Test      │
#        │                            │
#        ▼                            ▼
#  [5] Save Checkpoint ──→ [6] Load & Preprocess WelFake
#                                     │
#                                     ▼
#                             [7] TF-IDF + KNN Graph
#                                     │
#                                     ▼
#                             [8] GCN Inference
#                                     │
#                                     ▼
#                             [9] Cross-Dataset Evaluation
# ```

# %% [markdown]
# ---
# # 🏋️ PHẦN 1 — TRAINING TRÊN FAKENEWS

# %% [markdown]
# ## ⚙️ Cell 0 — Import thư viện & Cấu hình

# %%
import sys
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, accuracy_score, confusion_matrix
)
from scipy.sparse import csr_matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data

print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device          : {DEVICE}")
# Out:
# PyTorch version : 2.8.0
# CUDA available  : False
# Device          : cpu

# %%
# ── Tự động tìm PROJECT_ROOT ─────────────────────────────────────────────────
cwd = Path('.').resolve()
PROJECT_ROOT = cwd
for _ in range(4):
    if (PROJECT_ROOT / 'data').exists():
        break
    PROJECT_ROOT = PROJECT_ROOT.parent

RAW_DIR    = PROJECT_ROOT / 'data' / 'raw'
CKPT_DIR   = PROJECT_ROOT / 'output' / 'checkpoints'
CKPT_DIR.mkdir(parents=True, exist_ok=True)

CHECKPOINT  = CKPT_DIR / 'gcn_fakenews.pt'
FAKE_PATH   = RAW_DIR / 'fake.csv'
TRUE_PATH   = RAW_DIR / 'true.csv'
WELFAKE_PATH = RAW_DIR / 'WELFake_Dataset.csv'

print(f"PROJECT_ROOT  : {PROJECT_ROOT}")
print(f"fake.csv      : {FAKE_PATH}   (exists={FAKE_PATH.exists()})")
print(f"true.csv      : {TRUE_PATH}   (exists={TRUE_PATH.exists()})")
print(f"WELFake       : {WELFAKE_PATH}  (exists={WELFAKE_PATH.exists()})")
print(f"Checkpoint    : {CHECKPOINT}")

if not FAKE_PATH.exists() or not TRUE_PATH.exists():
    raise FileNotFoundError(
        f"❌ FakeNews CSV not found in {RAW_DIR}. Place fake.csv and true.csv there."
    )
if not WELFAKE_PATH.exists():
    raise FileNotFoundError(
        f"❌ WELFake_Dataset.csv not found in {RAW_DIR}."
    )
# Out:
# PROJECT_ROOT  : /Users/macbook/Documents/HK2_Nam3(2526)/Theory/Graph Mining/Fake-News-Detection-GNN
# fake.csv      : /Users/macbook/Documents/HK2_Nam3(2526)/Theory/Graph Mining/Fake-News-Detection-GNN/data/raw/fake.csv   (exists=True)
# true.csv      : /Users/macbook/Documents/HK2_Nam3(2526)/Theory/Graph Mining/Fake-News-Detection-GNN/data/raw/true.csv   (exists=True)
# WELFake       : /Users/macbook/Documents/HK2_Nam3(2526)/Theory/Graph Mining/Fake-News-Detection-GNN/data/raw/WELFake_Dataset.csv  (exists=True)
# Checkpoint    : /Users/macbook/Documents/HK2_Nam3(2526)/Theory/Graph Mining/Fake-News-Detection-GNN/output/checkpoints/gcn_fakenews.pt

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────────
SAMPLE_SIZE   = 3000    # Số articles dùng để train (-1 = toàn bộ)
MAX_FEATURES  = 2000    # Số chiều TF-IDF
KNN_K         = 5       # Số hàng xóm KNN
HIDDEN_DIM    = 128     # Hidden channels của GCN
EPOCHS        = 100     # Số epoch train
LR            = 0.001   # Learning rate
TEST_RATIO    = 0.2     # Tỷ lệ tập test
RANDOM_SEED   = 42

WELFAKE_SAMPLE_SIZE = 3000  # Số articles WelFake dùng để predict

print(f"SAMPLE_SIZE   : {SAMPLE_SIZE}")
print(f"MAX_FEATURES  : {MAX_FEATURES}")
print(f"KNN_K         : {KNN_K}")
print(f"HIDDEN_DIM    : {HIDDEN_DIM}")
print(f"EPOCHS        : {EPOCHS}")
print(f"LR            : {LR}")
# Out:
# SAMPLE_SIZE   : 3000
# MAX_FEATURES  : 2000
# KNN_K         : 5
# HIDDEN_DIM    : 128
# EPOCHS        : 100
# LR            : 0.001

# %% [markdown]
# ---
# ## 📂 Step 1 — Load & Preprocess FakeNews Dataset

# %%
print("=" * 60)
print("STEP 1: Loading FakeNews Dataset")
print("=" * 60)

fake_df = pd.read_csv(FAKE_PATH)
fake_df['label'] = 1  # 1 = Fake
print(f"  ✓ fake.csv : {len(fake_df):,} articles")

true_df = pd.read_csv(TRUE_PATH)
true_df['label'] = 0  # 0 = Real
print(f"  ✓ true.csv : {len(true_df):,} articles")

df_combined = pd.concat([fake_df, true_df], ignore_index=True)
print(f"  ✓ Combined : {len(df_combined):,} articles")
# Out:
# ...
# STEP 1: Loading FakeNews Dataset
# ...
#   ✓ fake.csv : 23,481 articles
#   ✓ true.csv : 21,417 articles
#   ✓ Combined : 44,898 articles

# %%
# ── Text preprocessing ───────────────────────────────────────────────────────
def preprocess_text(text: str) -> str:
    """Lowercase, remove punctuation, normalize whitespace."""
    text = str(text).lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return ' '.join(text.split())

df_combined['text']    = df_combined['text'].astype(str).apply(preprocess_text)
df_combined['title']   = df_combined['title'].astype(str).apply(preprocess_text)
df_combined['content'] = df_combined['title'] + " " + df_combined['text']

# ── Sampling ─────────────────────────────────────────────────────────────────
if SAMPLE_SIZE < 0:
    df_sample = df_combined.reset_index(drop=True)
    print(f"  ✓ Using ALL {len(df_sample):,} articles")
else:
    df_sample = df_combined.sample(
        n=min(SAMPLE_SIZE, len(df_combined)), random_state=RANDOM_SEED
    ).reset_index(drop=True)
    print(f"  ✓ Sampled {len(df_sample):,} articles")

y_data = df_sample['label'].values
fake_count = (y_data == 1).sum()
real_count = (y_data == 0).sum()
print(f"  ✓ Real: {real_count} ({real_count/len(y_data)*100:.1f}%)")
print(f"  ✓ Fake: {fake_count} ({fake_count/len(y_data)*100:.1f}%)")
# Out:
#   ✓ Sampled 3,000 articles
#   ✓ Real: 1397 (46.6%)
#   ✓ Fake: 1603 (53.4%)

# %% [markdown]
# ---
# ## 🧮 Step 2 — TF-IDF Feature Extraction & KNN Graph Construction

# %%
print("=" * 60)
print("STEP 2: Feature Extraction & Graph Construction")
print("=" * 60)

# TF-IDF
vectorizer   = TfidfVectorizer(max_features=MAX_FEATURES)
tfidf_matrix = vectorizer.fit_transform(df_sample['content']).toarray()
scaler       = StandardScaler()
tfidf_feats  = scaler.fit_transform(tfidf_matrix)
print(f"  ✓ TF-IDF shape : {tfidf_feats.shape}")

# Train/test split (index-based)
indices = np.arange(len(df_sample))
train_idx, test_idx = train_test_split(
    indices, test_size=TEST_RATIO, random_state=RANDOM_SEED, stratify=y_data
)
train_mask = torch.zeros(len(df_sample), dtype=torch.bool)
test_mask  = torch.zeros(len(df_sample), dtype=torch.bool)
train_mask[train_idx] = True
test_mask[test_idx]   = True
print(f"  ✓ Train: {train_mask.sum().item():,} | Test: {test_mask.sum().item():,}")

# KNN graph
nbrs = NearestNeighbors(n_neighbors=KNN_K + 1, algorithm='auto', metric='cosine')
nbrs.fit(tfidf_feats)
distances, indices_knn = nbrs.kneighbors(tfidf_feats)

rows, cols = [], []
for i in range(tfidf_feats.shape[0]):
    for j in range(1, KNN_K + 1):
        rows.append(i)
        cols.append(indices_knn[i][j])

data_val   = np.ones(len(rows))
adj        = csr_matrix((data_val, (rows, cols)),
                         shape=(tfidf_feats.shape[0], tfidf_feats.shape[0]))
adj        = adj.maximum(adj.transpose())
coo        = adj.tocoo()
edge_index = torch.tensor(np.array([coo.row, coo.col]), dtype=torch.long)

n_nodes = adj.shape[0]
n_edges = adj.count_nonzero()
print(f"  ✓ Nodes          : {n_nodes:,}")
print(f"  ✓ Edges (undir.) : {n_edges:,}")
print(f"  ✓ Avg degree     : {n_edges / n_nodes:.2f}")
print(f"  ✓ edge_index     : {edge_index.shape}")

# PyG Data object
X_tensor   = torch.tensor(tfidf_feats, dtype=torch.float32)
y_tensor   = torch.tensor(y_data, dtype=torch.long)
pyg_data   = Data(
    x=X_tensor,
    edge_index=edge_index,
    y=y_tensor,
    train_mask=train_mask,
    test_mask=test_mask
).to(DEVICE)
# Out:
# ...
# STEP 2: Feature Extraction & Graph Construction
# ...
#   ✓ TF-IDF shape : (3000, 2000)
#   ✓ Train: 2,400 | Test: 600
#   ✓ Nodes          : 3,000
#   ✓ Edges (undir.) : 21,399
#   ✓ Avg degree     : 7.13
#   ✓ edge_index     : torch.Size([2, 21399])

# %% [markdown]
# ---
# ## 🏗️ Step 3 — Define & Train GCN Model

# %%
class GCNModel(nn.Module):
    """2-layer Graph Convolutional Network for binary classification."""

    def __init__(self, in_channels: int, hidden_channels: int = 128, out_channels: int = 2):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, data: Data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x

# %%
print("=" * 60)
print("STEP 3: Training GCN Model")
print("=" * 60)

model     = GCNModel(in_channels=MAX_FEATURES, hidden_channels=HIDDEN_DIM).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

train_losses, test_accs = [], []

for epoch in range(1, EPOCHS + 1):
    # Training
    model.train()
    optimizer.zero_grad()
    out  = model(pyg_data)
    loss = criterion(out[pyg_data.train_mask], pyg_data.y[pyg_data.train_mask])
    loss.backward()
    optimizer.step()
    train_losses.append(loss.item())

    # Evaluation
    model.eval()
    with torch.no_grad():
        pred  = out.argmax(dim=1)
        acc   = (pred[pyg_data.test_mask] == pyg_data.y[pyg_data.test_mask]).float().mean().item()
    test_accs.append(acc)

    if epoch % 10 == 0 or epoch == 1:
        print(f"  Epoch {epoch:>3d}/{EPOCHS} | Loss: {loss.item():.4f} | Test Acc: {acc*100:.2f}%")

print(f"\n  ✅ Training complete! Best Test Acc: {max(test_accs)*100:.2f}%")
# Out:
# ...
# STEP 3: Training GCN Model
# ...
#   Epoch   1/100 | Loss: 0.7428 | Test Acc: 54.50%
#   Epoch  10/100 | Loss: 0.2709 | Test Acc: 87.50%
#   Epoch  20/100 | Loss: 0.1970 | Test Acc: 87.67%
#   Epoch  30/100 | Loss: 0.1629 | Test Acc: 86.33%
#   Epoch  40/100 | Loss: 0.1366 | Test Acc: 87.00%
#   Epoch  50/100 | Loss: 0.1147 | Test Acc: 86.00%
#   Epoch  60/100 | Loss: 0.0959 | Test Acc: 86.33%
#   Epoch  70/100 | Loss: 0.0796 | Test Acc: 85.67%
#   Epoch  80/100 | Loss: 0.0655 | Test Acc: 86.17%
#   Epoch  90/100 | Loss: 0.0536 | Test Acc: 86.00%
#   Epoch 100/100 | Loss: 0.0438 | Test Acc: 85.67%
#
#   ✅ Training complete! Best Test Acc: 88.00%

# %% [markdown]
# ---
# ## 📊 Step 4 — Evaluate on FakeNews Test Set

# %%
print("=" * 60)
print("STEP 4: Evaluation on FakeNews Test Set")
print("=" * 60)

model.eval()
with torch.no_grad():
    out   = model(pyg_data)
    preds = out.argmax(dim=1).cpu().numpy()

y_test       = pyg_data.y[pyg_data.test_mask].cpu().numpy()
preds_test   = preds[pyg_data.test_mask.cpu().numpy()]
test_acc     = accuracy_score(y_test, preds_test)

print(f"\n  ✅ Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)\n")
print(classification_report(y_test, preds_test, target_names=['Real (0)', 'Fake (1)']))

# Confusion matrix
cm = confusion_matrix(y_test, preds_test)
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred Real', 'Pred Fake'],
            yticklabels=['Actual Real', 'Actual Fake'],
            ax=ax, linewidths=0.5, linecolor='white')
ax.set_title(f'Confusion Matrix — FakeNews Test (Acc={test_acc*100:.1f}%)', fontweight='bold')
plt.tight_layout()
plt.show()

# Training curve
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(train_losses, color='#E05C5C', linewidth=1.5)
ax1.set_title('Training Loss', fontweight='bold')
ax1.set_xlabel('Epoch'); ax1.set_ylabel('CrossEntropyLoss')
ax2.plot([a*100 for a in test_accs], color='#4CAF93', linewidth=1.5)
ax2.set_title('Test Accuracy', fontweight='bold')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy (%)')
plt.suptitle('FakeNews Training Curve', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# ...
# STEP 4: Evaluation on FakeNews Test Set
# ...
#
#   ✅ Test Accuracy: 0.8567 (85.67%)
#
#               precision    recall  f1-score   support
#
#     Real (0)       0.84      0.85      0.85       279
#     Fake (1)       0.87      0.86      0.87       321
#
#     accuracy                           0.86       600
#    macro avg       0.86      0.86      0.86       600
# weighted avg       0.86      0.86      0.86       600

# %% [markdown]
# ---
# ## 💾 Step 5 — Save Checkpoint

# %%
print("=" * 60)
print("STEP 5: Saving Checkpoint")
print("=" * 60)

torch.save({
    'model_state_dict': model.state_dict(),
    'in_channels'     : MAX_FEATURES,
    'hidden_channels' : HIDDEN_DIM,
    'out_channels'    : 2,
    'test_accuracy'   : test_acc,
    'timestamp'       : datetime.now().isoformat(),
    'hyperparams'     : {
        'sample_size' : SAMPLE_SIZE,
        'max_features': MAX_FEATURES,
        'knn_k'       : KNN_K,
        'hidden_dim'  : HIDDEN_DIM,
        'epochs'      : EPOCHS,
        'learning_rate': LR,
    }
}, CHECKPOINT)

print(f"  ✓ Checkpoint saved to: {CHECKPOINT}")
print(f"  ✓ Test accuracy      : {test_acc*100:.2f}%")
# Out:
# ...
# STEP 5: Saving Checkpoint
# ...
#   ✓ Checkpoint saved to: /Users/macbook/Documents/HK2_Nam3(2526)/Theory/Graph Mining/Fake-News-Detection-GNN/output/checkpoints/gcn_fakenews.pt
#   ✓ Test accuracy      : 85.67%

# %% [markdown]
# ---
# # 🔮 PHẦN 2 — CROSS-DATASET INFERENCE TRÊN WELFAKE
#
# > Model **đã được train** ở Phần 1 sẽ được dùng trực tiếp (không cần load lại checkpoint).
# > TF-IDF được fit lại trên WelFake với cùng `max_features` để đảm bảo input dimension khớp.

# %% [markdown]
# ---
# ## 📂 Step 6 — Load & Preprocess WelFake Dataset

# %%
print("=" * 60)
print("STEP 6: Loading WelFake Dataset")
print("=" * 60)

welfake_df = pd.read_csv(WELFAKE_PATH)
print(f"  ✓ Total WelFake articles: {len(welfake_df):,}")
print(f"  ✓ Columns: {list(welfake_df.columns)}")

# WelFake label: 1=Fake, 0=Real
welfake_df = welfake_df.dropna(subset=['title', 'text', 'label']).reset_index(drop=True)
welfake_df['text']    = welfake_df['text'].astype(str).apply(preprocess_text)
welfake_df['title']   = welfake_df['title'].astype(str).apply(preprocess_text)
welfake_df['content'] = welfake_df['title'] + " " + welfake_df['text']

# Sampling
if WELFAKE_SAMPLE_SIZE < 0:
    wf_sample = welfake_df.reset_index(drop=True)
    print(f"  ✓ Using ALL {len(wf_sample):,} WelFake articles")
else:
    wf_sample = welfake_df.sample(
        n=min(WELFAKE_SAMPLE_SIZE, len(welfake_df)), random_state=RANDOM_SEED
    ).reset_index(drop=True)
    print(f"  ✓ Sampled {len(wf_sample):,} WelFake articles")

y_wf = wf_sample['label'].values.astype(int)
wf_fake  = (y_wf == 1).sum()
wf_real  = (y_wf == 0).sum()
print(f"  ✓ Real: {wf_real} ({wf_real/len(y_wf)*100:.1f}%)")
print(f"  ✓ Fake: {wf_fake} ({wf_fake/len(y_wf)*100:.1f}%)")
# Out:
# ...
# STEP 6: Loading WelFake Dataset
# ...
#   ✓ Total WelFake articles: 72,134
#   ✓ Columns: ['title', 'text', 'label']
#   ✓ Sampled 3,000 WelFake articles
#   ✓ Real: 1488 (49.6%)
#   ✓ Fake: 1512 (50.4%)

# %% [markdown]
# ---
# ## 🧮 Step 7 — TF-IDF + KNN Graph on WelFake
#
# > ⚠️ **Lưu ý:** TF-IDF được fit lại trên WelFake (inductive setting). Từ vựng khác nhau giữa 2 dataset là một trong những nguyên nhân chính làm giảm accuracy cross-dataset.

# %%
print("=" * 60)
print("STEP 7: Feature Extraction & Graph Construction (WelFake)")
print("=" * 60)

# TF-IDF với cùng MAX_FEATURES
wf_vectorizer   = TfidfVectorizer(max_features=MAX_FEATURES)
wf_tfidf_matrix = wf_vectorizer.fit_transform(wf_sample['content']).toarray()
wf_scaler       = StandardScaler()
wf_tfidf_feats  = wf_scaler.fit_transform(wf_tfidf_matrix)
print(f"  ✓ TF-IDF shape : {wf_tfidf_feats.shape}")

# KNN graph
wf_nbrs = NearestNeighbors(n_neighbors=KNN_K + 1, algorithm='auto', metric='cosine')
wf_nbrs.fit(wf_tfidf_feats)
_, wf_indices_knn = wf_nbrs.kneighbors(wf_tfidf_feats)

wf_rows, wf_cols = [], []
for i in range(wf_tfidf_feats.shape[0]):
    for j in range(1, KNN_K + 1):
        wf_rows.append(i)
        wf_cols.append(wf_indices_knn[i][j])

wf_data_val   = np.ones(len(wf_rows))
wf_adj        = csr_matrix((wf_data_val, (wf_rows, wf_cols)),
                            shape=(wf_tfidf_feats.shape[0], wf_tfidf_feats.shape[0]))
wf_adj        = wf_adj.maximum(wf_adj.transpose())
wf_coo        = wf_adj.tocoo()
wf_edge_index = torch.tensor(np.array([wf_coo.row, wf_coo.col]), dtype=torch.long)

n_nodes_wf = wf_adj.shape[0]
n_edges_wf = wf_adj.count_nonzero()
print(f"  ✓ Nodes          : {n_nodes_wf:,}")
print(f"  ✓ Edges (undir.) : {n_edges_wf:,}")
print(f"  ✓ Avg degree     : {n_edges_wf / n_nodes_wf:.2f}")
# Out:
# ...
# STEP 7: Feature Extraction & Graph Construction (WelFake)
# ...
#   ✓ TF-IDF shape : (3000, 2000)
#   ✓ Nodes          : 3,000
#   ✓ Edges (undir.) : 21,481
#   ✓ Avg degree     : 7.16

# %% [markdown]
# ---
# ## 🔮 Step 8 — GCN Inference on WelFake

# %%
print("=" * 60)
print("STEP 8: Inference on WelFake")
print("=" * 60)

wf_X_tensor   = torch.tensor(wf_tfidf_feats, dtype=torch.float32).to(DEVICE)
wf_y_tensor   = torch.tensor(y_wf, dtype=torch.long).to(DEVICE)
wf_edge_dev   = wf_edge_index.to(DEVICE)

wf_pyg_data = Data(x=wf_X_tensor, edge_index=wf_edge_dev, y=wf_y_tensor)

start_time = datetime.now()
model.eval()  # Dùng model đã train ở Phần 1
with torch.no_grad():
    wf_out   = model(wf_pyg_data)
    wf_probs = torch.softmax(wf_out, dim=1).cpu().numpy()
    wf_preds = wf_out.argmax(dim=1).cpu().numpy()
    wf_true  = wf_y_tensor.cpu().numpy()

elapsed = (datetime.now() - start_time).total_seconds()
print(f"  ✓ Inference completed in {elapsed:.2f}s")
print(f"  ✓ Predicted {len(wf_preds):,} samples")
print(f"  ✓ Predicted Fake: {(wf_preds == 1).sum():,}  |  Predicted Real: {(wf_preds == 0).sum():,}")
# Out:
# ...
# STEP 8: Inference on WelFake
# ...
#   ✓ Inference completed in 0.01s
#   ✓ Predicted 3,000 samples
#   ✓ Predicted Fake: 1,930  |  Predicted Real: 1,070

# %% [markdown]
# ---
# ## 📊 Step 9 — Cross-Dataset Evaluation (FakeNews → WelFake)

# %%
print("=" * 60)
print("STEP 9: Cross-Dataset Evaluation Results")
print("=" * 60)

wf_acc = accuracy_score(wf_true, wf_preds)
print(f"\n  ✅ Accuracy on WelFake (cross-dataset): {wf_acc:.4f} ({wf_acc*100:.2f}%)\n")
print(classification_report(wf_true, wf_preds, target_names=['Real (0)', 'Fake (1)']))

# Confusion matrix
wf_cm = confusion_matrix(wf_true, wf_preds)
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(wf_cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=['Pred Real', 'Pred Fake'],
            yticklabels=['Actual Real', 'Actual Fake'],
            ax=ax, linewidths=0.5, linecolor='white')
ax.set_title(f'Confusion Matrix — WelFake (Acc={wf_acc*100:.1f}%)', fontweight='bold')
plt.tight_layout()
plt.show()

# Confidence distribution
wf_prob_fake = wf_probs[:, 1]
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
axes[0].hist(wf_prob_fake[wf_true == 0], bins=40, alpha=0.7, color='#4CAF93', label='Actual Real')
axes[0].hist(wf_prob_fake[wf_true == 1], bins=40, alpha=0.7, color='#E05C5C', label='Actual Fake')
axes[0].axvline(0.5, color='gray', linestyle='--', linewidth=1.5, label='Threshold=0.5')
axes[0].set_xlabel('P(Fake)'); axes[0].set_ylabel('Count')
axes[0].set_title('Prediction Confidence Distribution', fontweight='bold')
axes[0].legend()

pred_labels = ['Pred Real', 'Pred Fake']
pred_counts = [(wf_preds == 0).sum(), (wf_preds == 1).sum()]
axes[1].bar(pred_labels, pred_counts, color=['#4CAF93', '#E05C5C'],
            edgecolor='white', linewidth=1.5, width=0.5)
axes[1].set_title('Prediction Count Summary', fontweight='bold')
axes[1].set_ylabel('Count')
for i, v in enumerate(pred_counts):
    axes[1].text(i, v + 20, str(v), ha='center', fontweight='bold')

plt.suptitle('WelFake — Cross-Dataset Prediction Analysis', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# ...
# STEP 9: Cross-Dataset Evaluation Results
# ...
#
#   ✅ Accuracy on WelFake (cross-dataset): 0.5213 (52.13%)
#
#               precision    recall  f1-score   support
#
#     Real (0)       0.52      0.38      0.44      1488
#     Fake (1)       0.52      0.66      0.58      1512
#
#     accuracy                           0.52      3000
#    macro avg       0.52      0.52      0.51      3000
# weighted avg       0.52      0.52      0.51      3000

# %%
# ── Tổng kết ─────────────────────────────────────────────────────────────────
tn, fp, fn, tp = wf_cm.ravel()
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall    = tp / (tp + fn) if (tp + fn) > 0 else 0
f1        = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

print(f"{'='*60}")
print(f"  📋 FULL PIPELINE SUMMARY")
print(f"{'='*60}")
print(f"  Train dataset    : FakeNews ({SAMPLE_SIZE:,} samples)")
print(f"  Test dataset     : WelFake ({len(wf_preds):,} samples)")
print(f"  FakeNews Test Acc: {test_acc*100:.2f}%")
print(f"  WelFake Accuracy : {wf_acc*100:.2f}%  (cross-dataset)")
print(f"  Precision (Fake) : {precision:.4f}")
print(f"  Recall (Fake)    : {recall:.4f}")
print(f"  F1-Score (Fake)  : {f1:.4f}")
print(f"{'='*60}")
print(f"  ✅ PIPELINE COMPLETED")
print(f"{'='*60}")
# Out:
# ...
#   📋 FULL PIPELINE SUMMARY
# ...
#   Train dataset    : FakeNews (3,000 samples)
#   Test dataset     : WelFake (3,000 samples)
#   FakeNews Test Acc: 85.67%
#   WelFake Accuracy : 52.13%  (cross-dataset)
#   Precision (Fake) : 0.5197
#   Recall (Fake)    : 0.6634
#   F1-Score (Fake)  : 0.5828
# ...
#   ✅ PIPELINE COMPLETED
# ...
